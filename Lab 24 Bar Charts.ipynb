# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Bar Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on visualizing data.
#
# The dataset will be provided to you in the form of an RDBMS.
#
# You will use SQL queries to extract the necessary data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data
#
# -   Visualize the relationship between two features
#
# -   Visualize the composition of data
#
# -   Visualize comparison of data

# %% [markdown]
# ## Setup: Working with the Database
# **Install the needed libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 168.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 154.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 86.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 165.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2026-07-29 13:31:46--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  47.0MB/s    in 3.5s
#
# 2026-07-29 13:31:50 (43.5 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Distributions

# %% [markdown]
# ##### 1. Histogram of `ConvertedCompYearly`

# %% [markdown]
# Visualize the distribution of yearly compensation (`ConvertedCompYearly`) using a histogram.

# %%
df_clean = df["ConvertedCompYearly"].dropna()
plt.figure(figsize=(8,6))
plt.hist(df_clean, bins=40, color="blue", edgecolor="black")
plt.xlabel("Annual Compensation (USD)")
plt.ylabel("Number of Respondent")
plt.title("Histogram of Annual Compensation")
plt.show()

# %% [markdown]
# ##### 2. Box Plot of `Age`

# %% [markdown]
# Since `Age` is categorical in the dataset, convert it to numerical values for a box plot.

# %%
age_map = {
    "Under 18 years old": 16,
    "18-24 years old": 21,
    "25-34 years old": 29,
    "35-44 years old": 39,
    "45-54 years old": 49,
    "55-64 years old": 59,
    "65 years or older": 70
}
df["AgeNum"] = df["Age"].map(age_map)
age_clean = df["AgeNum"].dropna()
plt.figure(figsize=(8,6))
plt.boxplot(age_clean, patch_artist=True, boxprops=dict(facecolor="skyblue", color="black"), medianprops=dict(color="red"))
plt.xlabel("Age")
plt.title("Box Plot of Age")
plt.show()

# %% [markdown]
# ### Task 2: Visualizing Relationships in Data

# %% [markdown]
# ##### 1. Scatter Plot of `Age_numeric` and `ConvertedCompYearly`

# %% [markdown]
# Explore the relationship between age and compensation.

# %%
df_clean = df.dropna(subset=["AgeNum", "ConvertedCompYearly"])
plt.figure(figsize=(8,6))
plt.scatter(df_clean["AgeNum"], df_clean["ConvertedCompYearly"], alpha=0.5, color="blue")
plt.xlabel("Age")
plt.ylabel("Annual Compensation(USD)")
plt.title("Scatter Plot: Age vs Annual Compensation")
plt.xticks([16,21,29,39,49,59,70],
           ["<18","18-24","25-34","35-44","45-54","55-64","65+"])
plt.show()

# %% [markdown]
# ##### 2. Bubble Plot of `ConvertedCompYearly` and `JobSatPoints_6` with `Age_numeric` as Bubble Size

# %% [markdown]
# Explore how compensation and job satisfaction are related, with age as the bubble size.

# %%
df_comp = df.dropna(subset=["AgeNum", "ConvertedCompYearly", "JobSatPoints_6"])
plt.figure(figsize=(8,6))
plt.scatter(df_comp["ConvertedCompYearly"], df_comp["JobSatPoints_6"], s=df_comp["AgeNum"]*2, alpha=0.5, color="blue")
plt.xlabel("Annual Compensation(USD)")
plt.ylabel("Job Satisfaction")
plt.title("Bubble Plot: ConvertedCompYearly vs JobSatPoints_6 (Bubble Size=Age)")
plt.show()

# %% [markdown]
# ### Task 3: Visualizing Composition of Data with Bar Charts

# %% [markdown]
# ##### 1. Horizontal Bar Chart of `MainBranch` Distribution

# %% [markdown]
# Visualize the distribution of respondents’ primary roles to understand their professional focus.

# %%
branch_count = df["MainBranch"].value_counts()
df_clean = branch_count.dropna()
plt.figure(figsize=(8,6))
plt.barh(df_clean.index, df_clean.values, color="blue", edgecolor="black")
plt.xlabel("Number of Respondent")
plt.ylabel("Mainbranch")
plt.title("Horizontal Bar Chart of MainBranch Distribution")
plt.show()

# %% [markdown]
# ##### 2. Vertical Bar Chart of Top 5 Programming Languages Respondents Want to Work With

# %% [markdown]
# Identify the most desired programming languages based on `LanguageWantToWorkWith`.

# %%
lang_serie = df["LanguageWantToWorkWith"].dropna().str.split(";").explode().str.strip()
top5 = lang_serie.value_counts().nlargest(5)
plt.figure(figsize=(8,6))
plt.bar(top5.index, top5.values, color="blue", edgecolor="black")
plt.xlabel("Programme Language")
plt.ylabel("Number of Respondent")
plt.title("Vertical Bar Chart of Top 5 Programming Languages Respondents Want to Work With")
plt.show()

# %% [markdown]
# ##### 3. Stacked Bar Chart of Median `JobSatPoints_6` and `JobSatPoints_7` by Age Group

# %% [markdown]
# Compare job satisfaction metrics across different age groups with a stacked bar chart.

# %%
age_groups = [
    "Under 18 years old",
    "18-24 years old",
    "25-34 years old",
    "35-44 years old",
    "45-54 years old",
    "55-64 years old",
    "65 years or older"
]
df_age = df[df["Age"].isin(age_groups)]
median_age = df_age.groupby("Age")[["JobSatPoints_6", "JobSatPoints_7"]].median()
median_age.plot(kind="bar", stacked=True, figsize=(8,6))
plt.xlabel("Age Group")
plt.ylabel("Job Satisfaction")
plt.title("Median JobSatPoints_6 and JobSatPoints_7 by Age Group")
plt.legend(["JobSatPoints_6", "JobSatPoints_7"])
plt.show()

# %% [markdown]
# ##### 4. Bar Chart of Database Popularity (`DatabaseHaveWorkedWith`)

# %% [markdown]
# Identify the most commonly used databases among respondents by visualizing `DatabaseHaveWorkedWith`.

# %%
db_series = df["DatabaseHaveWorkedWith"].dropna().str.split(";").explode().str.strip()
db_counts = db_series.value_counts()
plt.figure(figsize=(10,6))
plt.bar(db_counts.index, db_counts.values, color="skyblue", edgecolor="black")
plt.title("Database Popularity (DatabaseHaveWorkedWith)")
plt.xlabel("Database")
plt.ylabel("Number of Respondents")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# ### Task 4: Visualizing Comparison of Data with Bar Charts

# %% [markdown]
# ##### 1. Grouped Bar Chart of Median `ConvertedCompYearly` for Different Age Groups

# %% [markdown]
# Compare median compensation across multiple age groups with a grouped bar chart.

# %%
age_groups = [
    "Under 18 years old",
    "18-24 years old",
    "25-34 years old",
    "35-44 years old",
    "45-54 years old",
    "55-64 years old",
    "65 years or older"
]
df_age = df[df["Age"].isin(age_groups)]
median_comp = df_age.groupby("Age")["ConvertedCompYearly"].median()
plt.figure(figsize=(8,6))
plt.bar(median_comp.index, median_comp.values, color="skyblue", edgecolor="black")
plt.xlabel("Age Group")
plt.ylabel("Annual Compensation(USD)")
plt.title("Grouped Bar Chart of Median Compensation for Age Group")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# ##### 2. Bar Chart of Respondent Count by Country

# %% [markdown]
# Show the distribution of respondents by country to see which regions are most represented.

# %%
country_count = df["Country"].value_counts()
plt.figure(figsize=(8,6))
plt.bar(country_count.index, country_count.values, color="skyblue", edgecolor="black")
plt.xlabel("Country")
plt.ylabel("Number of Respondents")
plt.title("Bar Chart of Respondent Count by Country")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# This lab demonstrates how to create and interpret different types of bar charts, allowing you to analyze the composition, comparison, and distribution of categorical data in the Stack Overflow dataset, including main professional branches, programming language preferences, and compensation by age group. Bar charts effectively compare counts and median values across various categories.

# %% [markdown]
# ## Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create a horizontal bar chart to visualize the distribution of respondents' primary roles, helping to understand their professional focus.
# - Develop a vertical bar chart to identify the most desired programming languages based on the LanguageWantToWorkWith variable.
# - Use a stacked bar chart to compare job satisfaction metrics across different age groups.
# - Create a bar chart to visualize the most commonly used databases among respondents using the DatabaseHaveWorkedWith variable.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
