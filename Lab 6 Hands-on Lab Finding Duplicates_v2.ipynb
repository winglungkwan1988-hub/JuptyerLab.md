# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 127.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 137.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 144.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 147.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 98.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 150.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())

rows, cols = df.shape
print(f"總行數(受訪者數): {rows}")
print(f"總欄位數: {cols}")
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
duplicates = df.duplicated()
num_duplicates = duplicates.sum()
print("Number of duplicate rows:", num_duplicates)

all_duplicate_rows = df[df.duplicated(keep=False)].head(10)
print("\nFirst few duplicate groups (include original rows):")
print(all_duplicate_rows)
# Out:
# Number of duplicate rows: 0
# First few duplicate groups (include original rows):
# Empty DataFrame
# ...

# %% [markdown]
# ### Task 2: Analysis of Duplicate Response Patterns
# 1. Identify duplicate response patterns based on selected columns such as MainBranch, Employment, and RemoteWork.
# 2. Clarify that these represent multiple respondents with identical answers rather than duplicate records. Analyse which other columns frequently share identical values within these response-pattern groups.

# %%
grouped = df.groupby(['MainBranch', 'Employment', 'RemoteWork'])
patterns = grouped.size().reset_index(name="count")
duplicate_pattern = patterns[patterns["count"] > 1]
print("duplicate response patterns:")
print(duplicate_pattern)

for _, row in duplicate_pattern.iterrows():
    subset = df[
    (df['MainBranch'] == row['MainBranch']) &
    (df['Employment'] == row['Employment']) &
    (df['RemoteWork'] == row['RemoteWork'])
    ]
    print("\nPattern:", row['MainBranch'], row['Employment'], row['RemoteWork'])
    print("Count:", row["count"])

    for col in ['Age', 'LanguageHaveWorkedWith', 'LearnCode']:
        print(f"{col} mode:", subset[col].mode().tolist())
# Out:
# duplicate response patterns:
#                                             MainBranch  \
# 0                       I am a developer by profession
# 1                       I am a developer by profession
# 2                       I am a developer by profession
# 3                       I am a developer by profession
# 4                       I am a developer by profession
# ..                                                 ...
# 438  I used to be a developer by profession, but no...
# 442  I used to be a developer by profession, but no...
# 443  I used to be a developer by profession, but no...
# 444  I used to be a developer by profession, but no...
# 448  I used to be a developer by profession, but no...
#
#                                             Employment  \
# 0                                  Employed, full-time
# 1                                  Employed, full-time
# 2                                  Employed, full-time
# ...

# %% [markdown]
# ### Task 3: Visualize Shared Response Patterns
# 1. Create visualizations to show the distribution of shared response patterns across different categories.
# 2. Use bar charts or pie charts to represent the distribution of respondents who share identical values for MainBranch, Employment, and RemoteWork, grouped by Country and Employment.

# %%
plt.rcParams['figure.figsize'] = (14, 7)
plt.rcParams['font.size'] = 10

pattern_cols = ["MainBranch", "Employment", "RemoteWork"]
df_pattern = df[pattern_cols].fillna("Missing").copy()
df['response_pattern'] = df_pattern.agg(lambda x: " | ".join(x), axis=1)

top5_patterns = df['response_pattern'].value_counts().head(5).index.tolist()
df_top_pattern = df[df['response_pattern'].isin(top5_patterns)].copy()
top8_countries = df["Country"].value_counts().head(8).index.tolist()
df_plot = df_top_pattern[df_top_pattern["Country"].isin(top8_countries)].copy()

def shorten_label(text):
    if "Hybrid" in text:
        return "Full‑time | Hybrid"
    elif "In‑person" in text:
        return "Full‑time | In‑person"
    elif "Remote" in text and "full‑time" in text:
        return "Full‑time | Remote"
    elif "Independent contractor" in text:
        return "Contractor | Remote"
    else:
        return text[:30]

df_plot["short_pattern"] = df_plot["response_pattern"].apply(shorten_label)
plt.figure(figsize=(18,10))
group_counts = df_plot.groupby(["Country","Employment","short_pattern"]).size().reset_index(name="respondent_count")

pivot_df = group_counts.pivot_table(
    index="Country",
    columns=["Employment","short_pattern"],
    values="respondent_count",
    fill_value=0
)

pivot_df.plot(kind="bar", stacked=True, ax=plt.gca())
plt.title("Distribution of shared response patterns grouped by Country and Employment", fontsize=15)
plt.ylabel("Number of respondents", fontsize=12)
plt.xlabel("Country", fontsize=12)
plt.xticks(rotation=30, ha="right")

plt.legend(title="Employment & Response Pattern", bbox_to_anchor=(1.03,1), loc="upper left", fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 4: Evaluate Duplicate Handling Strategy
# 1. Analyse the dataset to determine which column(s) define record uniqueness.
# 2. Assess whether removing rows based on a subset of columns (rather than complete row duplication) is appropriate.
# Justify your decision with reference to the structure and purpose of the dataset.

# %% [raw]
# #### Columns defining record uniqueness
#
# In this Stack Overflow survey dataset, the `ResponseId` column uniquely identifies each respondent. Every row corresponds to one individual participant, and `ResponseId` contains no duplicates. Other columns such as `MainBranch`, `Employment` and `RemoteWork` cannot define uniqueness. Multiple different respondents can legitimately share identical values in these fields.
#
# #### Suitability of removing rows based on partial columns
#
# It is **not appropriate** to delete rows solely based on duplicate patterns in `MainBranch`, `Employment` and `RemoteWork`.
#
# The dataset structure shows that there are zero full‑row duplicate rows. Groups with matching values across these three columns are separate human respondents with similar answers, not corrupted duplicate records. Even when respondents share these three answers, they often differ in other important attributes including age, country, salary, education and technology‑use columns.
#
# This survey dataset is intended for statistical analysis of developer populations. Removing records by partial‑column matches would reduce sample size artificially, distort frequency counts and bias downstream statistics such as salary and demographic distributions.
#
# #### Final decision
#
# No rows should be removed based on partial‑column response patterns. The only valid duplicate‑removal scenario would be full‑row exact duplicates, which do not exist in this dataset. Therefore, no duplicate‑row deletion is required.

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# ### Task 5: Documentation of duplicate identification and removal process
#
# #### Objective
#
# This process aims to detect full‑row duplicate records and partial‑column duplicate response patterns in the Stack Overflow survey dataset, evaluate whether any records should be removed, and document all findings and decisions.
#
# #### Step 1: Detect full‑row duplicates
#
# Code used:
#
# ```
# full_row_duplicates = df.duplicated().sum()
# print(f"Full‑row duplicate count: {full_row_duplicates}")
# ```
#
# Observation: **0 full‑row duplicate rows** were detected.
# Every record represents a unique survey respondent, identified by the unique `ResponseId` field. No identical complete records exist in the dataset. The original dataset contains **65457 rows and 114 columns**.
#
# #### Step 2: Detect partial‑column duplicate response patterns
#
# We searched for groups of respondents sharing identical values for `MainBranch`, `Employment` and `RemoteWork`. These are not true duplicate records, but shared response patterns from different participants.
# Code used:
#
# ```
# pattern_cols = ["MainBranch","Employment","RemoteWork"]
# pattern_groups = df.groupby(pattern_cols).size().reset_index(name="count")
# repeated_patterns = pattern_groups[pattern_groups["count"]>1]
# print(f"Number of repeated response‑pattern groups: {len(repeated_patterns)}")
# ```
#
# Observation: 319 repeated response‑pattern groups were found.
# The largest group had 15286 respondents: professional full‑time developers with hybrid working arrangements. Respondents within the same pattern group still had unique `ResponseId` and varied values for age, country, programming languages and other survey fields.
#
# #### Step3: Evaluate duplicate‑removal suitability
#
# 1. Record uniqueness is defined by `ResponseId`. Each row corresponds to one distinct human respondent.
# 2. Partial‑column matches (identical `MainBranch`, `Employment`, `RemoteWork`) are normal survey outcomes, **not data‑quality errors**. Multiple different people can give the same answers to these three questions.
# 3. Deleting rows based only on these three columns would artificially reduce sample size, corrupt statistical counts and distort demographic and technical‑background analysis.
# 4. There are zero full‑row true duplicates which would normally qualify for removal.
#
# #### Step4: Final processing decision
#
# **No rows were removed from the dataset.**
#
# - No full‑row exact duplicates exist to clean.
# - Shared partial‑column response patterns are valid survey responses and must be retained for statistical analysis.
#
# #### Summary of dataset changes
#
# | Processing step | Number of rows before | Number of rows after | Rows removed |
# | --- | --- | --- | --- |
# | Full‑row duplicate check | 65457 | 65457 | 0 |
# | Partial pattern analysis | 65457 | 65457 | 0 |
#
# No data deletion operations were performed. The original dataset is preserved for subsequent analysis.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# Duplicate detection logic depends on **what defines a unique record in the dataset**.
#
# 1. **`ResponseId` — the correct unique‑identifier column**
# `ResponseId` is designed as the unique participant ID for this survey. One value maps to exactly one survey respondent.
#
# - If we wanted to detect real duplicate submissions (the same person submitting the survey multiple times), `ResponseId` is the correct column to check.
# - In this dataset, every `ResponseId` occurs exactly once, confirming there are no duplicate‑person records.
#
# 2. Why we should **not** choose `MainBranch`, `Employment`, `RemoteWork` for duplicate removal
# These three columns describe survey answers, not record identity. Many different real‑world respondents naturally share the same answers to these questions. Matching values here only mean similar responses, **not that the record is a duplicate copy**.
# Using these columns to drop rows would incorrectly treat different people as duplicates. This would remove valid survey data, reduce sample size from 65457 and bias statistical outputs.
# 3. Full‑row duplicate check (`df.duplicated()`‑checks all columns)
# Checking the entire row is used to detect accidental full copies of the whole record, for example when raw data is imported twice.
# A full‑row match means every field is identical, which strongly suggests a data‑import error rather than two different respondents.
# In our dataset, zero full‑row duplicates were found.
#
# ##### Key rule for choosing duplicate‑check columns
#
# Select columns that represent the **real‑world identity of the entity each row represents**.
#
# - If each row represents a person: use the person‑unique ID (`ResponseId`).
# - If each row represents a transaction: use transaction ID.
# Do **not** use descriptive answer columns for duplicate removal, even when values repeat.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
