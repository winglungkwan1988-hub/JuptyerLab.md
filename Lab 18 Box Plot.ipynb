# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Box Plots**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this lab, you will focus on the visualization of data. The dataset will be provided through an RDBMS, and you will need to use SQL queries to extract the required data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize data composition and comparisons using box plots.

# %% [markdown]
# ### Setup: Connecting to the Database

# %% [markdown]
# #### 1. Download the Database File

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite
# Out:
# --2026-07-27 07:16:19--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 211415040 (202M) [application/octet-stream]
# Saving to: ‘survey-results-public.sqlite’
#
# survey-results-publ 100%[===================>] 201.62M  37.6MB/s    in 5.5s
#
# 2026-07-27 07:16:27 (36.9 MB/s) - ‘survey-results-public.sqlite’ saved [211415040/211415040]

# %% [markdown]
# #### 2. Connect to the Database

# %% [markdown]
# **Install the needed libraries**

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 138.3 MB/s eta 0:00:00
# Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 149.2 MB/s eta 0:00:00
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.5.1 pandas-3.0.5

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.25 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 99.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 121.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 77.6 MB/s eta 0:00:00
# Downloading pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 115.8 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Connect to the SQLite database
conn = sqlite3.connect('survey-results-public.sqlite')

# %% [markdown]
# ## Demo: Basic SQL Queries

# %% [markdown]
# #### Demo 1: Count the Number of Rows in the Table

# %%
QUERY = "SELECT COUNT(*) FROM main"
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    COUNT(*)
# 0     65437

# %% [markdown]
# #### Demo 2: List All Tables

# %%
QUERY = """
SELECT name as Table_Name 
FROM sqlite_master 
WHERE type = 'table'
"""
pd.read_sql_query(QUERY, conn)
# Out:
#   Table_Name
# 0       main

# %% [markdown]
# #### Demo 3: Group Data by Age

# %%
QUERY = """
SELECT Age, COUNT(*) as count 
FROM main 
GROUP BY Age 
ORDER BY Age
"""
df_age = pd.read_sql_query(QUERY, conn)
print(df_age)
# Out:
#                   Age  count
# 0     18-24 years old  14098
# 1     25-34 years old  23911
# 2     35-44 years old  14942
# 3     45-54 years old   6249
# 4     55-64 years old   2575
# 5   65 years or older    772
# 6   Prefer not to say    322
# 7  Under 18 years old   2568

# %% [markdown]
# ## Visualizing Data

# %% [markdown]
# ### Task 1: Visualizing the Distribution of Data

# %% [markdown]
# **1. Box Plot of `CompTotal` (Total Compensation)**

# %% [markdown]
# Use a box plot to analyze the distribution and outliers in total compensation.

# %%
QUERY = "SELECT ConvertedCompYearly FROM main"
df_comp = pd.read_sql_query(QUERY, conn)

df_clean = df_comp["ConvertedCompYearly"].dropna()

df_clean.plot.box(figsize=(8,6))

plt.title("Boxplot of ConvertedCompYearly")
plt.xlabel("Yearly Compensation (USD)")
plt.show()

# %% [markdown]
# **2. Box Plot of Age (converted to numeric values)**

# %% [markdown]
# Convert the `Age` column into numerical values and visualize the distribution.

# %%
age_map = {
    "Under 18 years old": 16,
    "18-24 years old": 21,
    "25-34 years old": 29,
    "35-44 years old": 39,
    "45-54 years old": 49,
    "55-64 years old": 59,
    "65 years old or older": 70
}
QUERY = "SELECT Age FROM main"
df_age = pd.read_sql_query(QUERY, conn)
df_age["AgeNum"] = df_age["Age"].map(age_map)
df_clean = df_age.dropna(subset=["AgeNum"])
plt.figure(figsize=(8,6))
plt.boxplot(
    df_clean["AgeNum"],
    patch_artist=True,
    orientation="horizontal",
    boxprops=dict(facecolor="lightblue", color="black"),
    medianprops=dict(color="red")
)
plt.title("Boxplot of Age (Converted to Numeric)")
plt.xlabel("Age (Years)")
plt.show()

# %% [markdown]
# ### Task 2: Visualizing Relationships in Data

# %% [markdown]
# **1. Box Plot of `CompTotal` Grouped by Age Groups:**

# %% [markdown]
# Visualize the distribution of compensation across different age groups.

# %%
QUERY = "SELECT Age, ConvertedCompYearly FROM main"
df_Total = pd.read_sql_query(QUERY, conn)

age_map = {
    "Under 18 years old": 16,
    "18-24 years old": 21,
    "25-34 years old": 29,
    "35-44 years old": 39,
    "45-54 years old": 49,
    "55-64 years old": 59,
    "65 years old or older": 70
}
df_Total["AgeGroup"] = df_Total["Age"].map(age_map)
df_clean = df_Total.dropna(subset=["AgeGroup", "ConvertedCompYearly"])

df_clean.boxplot(column="ConvertedCompYearly", by="AgeGroup", figsize=(12,6))

plt.title("Boxplot of Yearly Compensation by Age Group")
plt.suptitle("")
plt.xlabel("Age Group")
plt.ylabel("Yearly Compensation (USD)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **2. Box Plot of `CompTotal` Grouped by Job Satisfaction (`JobSatPoints_6`):**

# %% [markdown]
# Examine how compensation varies based on job satisfaction levels.

# %%
QUERY = "SELECT ConvertedCompYearly, JobSatPoints_6 FROM main"
df_job = pd.read_sql_query(QUERY, conn)

df_clean = df_job.dropna(subset=["ConvertedCompYearly", "JobSatPoints_6"])

df_clean.boxplot(column="ConvertedCompYearly", by="JobSatPoints_6", figsize=(12,6))
plt.xlabel("Job Satisfaction (Points)")
plt.ylabel("Yearly Compensation (USD)")
plt.title("Boxplot of Yearly Compensation by Job Satisfaction")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Task 3: Visualizing the Composition of Data

# %% [markdown]
# **1. Box Plot of `ConvertedCompYearly` for the Top 5 Developer Types:**

# %% [markdown]
# Analyze compensation across the top 5 developer roles.

# %%
QUERY = "SELECT ConvertedCompYearly, DevType FROM main"
df_type = pd.read_sql_query(QUERY, conn)

top5_devtypes = df_type["DevType"].value_counts().nlargest(5).index

df_top5 = df_type[df_type["DevType"].isin(top5_devtypes)].dropna(subset=["ConvertedCompYearly"])

df_top5.boxplot(column="ConvertedCompYearly", by="DevType", figsize=(12,6))

plt.xlabel("Developer Type")
plt.ylabel("Yearly Compensation (USD)")
plt.title("Boxplot of Yearly Compensation for Top 5 Developer Types")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **2. Box Plot of `CompTotal` for the Top 5 Countries:**

# %% [markdown]
# Analyze compensation across respondents from the top 5 countries.

# %%
QUERY = "SELECT ConvertedCompYearly, Country FROM main"
df_comp = pd.read_sql_query(QUERY, conn)

top5_country = df_comp["Country"].value_counts().nlargest(5).index
df_top5 = df_comp[df_comp["Country"].isin(top5_country)].dropna(subset=["ConvertedCompYearly"])

df_top5.boxplot(column="ConvertedCompYearly", by="Country", figsize=(12,6))

plt.xlabel("Country")
plt.ylabel("Yearly Compensation (USD)")
plt.title("Boxplot of Yearly Compensation for Top 5 Countries")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Task 4: Visualizing Comparison of Data

# %% [markdown]
# **1. Box Plot of CompTotal Across Employment Types:**

# %% [markdown]
# Analyze compensation for different employment types.

# %%
QUERY = "SELECT Employment, ConvertedCompYearly FROM main"
df_emp = pd.read_sql_query(QUERY, conn)

df_clean = df_emp.dropna(subset=["Employment", "ConvertedCompYearly"])

df_clean.boxplot(column="ConvertedCompYearly", by="Employment", figsize=(12,6))

plt.title("Boxplot of Total Compensation by Employment Type")
plt.xlabel("Employment Type")
plt.ylabel("Total Compensation (USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **2. Box Plot of `YearsCodePro` by Job Satisfaction (`JobSatPoints_6`):**

# %% [markdown]
# Examine the distribution of professional coding years by job satisfaction levels.

# %%
QUERY = "SELECT YearsCodePro, JobSatPoints_6 FROM main"
df_level = pd.read_sql_query(QUERY, conn)

df_level["YearsCodePro"] = pd.to_numeric(df_level["YearsCodePro"], errors="coerce")

df_clean = df_level.dropna(subset=["JobSatPoints_6", "YearsCodePro"])

df_clean.boxplot(column="YearsCodePro", by="JobSatPoints_6", figsize=(12,6))

plt.title("Boxplot of YearsCodePro by Job Satisfaction")
plt.xlabel("Job Satisfaction (Points)")
plt.ylabel("Years of Professional Coding Experience")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Final Step: Close the Database Connection

# %% [markdown]
# After completing the lab, close the connection to the SQLite database:

# %%
conn.close()

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you used box plots to visualize various aspects of the dataset, focusing on:
#
# - Visualize distributions of compensation and age.
#
# - Explore relationships between compensation, job satisfaction, and professional coding experience.
#
# - Analyze data composition across developer roles and countries.
#
# - Compare compensation across employment types and satisfaction levels.
#
# Box plots provided clear insights into the spread, outliers, and central tendencies of various features in the dataset.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-07|1.2|Madhusudan Moole|Reviewed and updated lab|
# |2024-10-06|1.0|Raghul Ramesh|Created lab|-->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
